# %% [markdown]
# # DCGAN keras Imagenes 128 x 128

# %%
jupyter notebook --NotebookApp.max_buffer_size=6000000000
# Out:
#   File "<ipython-input-1-8d2daf772e1a>", line 1
#     jupyter notebook --NotebookApp.max_buffer_size=6000000000
#                    ^
# SyntaxError: invalid syntax

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %%
from __future__ import print_function, division

#Se importan las bibliotecas. En caso de querer hacer este proceso directamente
#en un ordenador se deben instalar las bilbiotecas que se indican a continuacion:

import numpy as np
import cv2
import matplotlib.pyplot as plt
import pickle
import h5py
import sklearn
import glob
import keras
import time
import imp
import os
import tensorflow as tf 
import pandas as pd
import sys

#Estas bibliotecas no son necesarias en su totalidad, solo se requieren ciertas
#funciones
from random import shuffle
from skimage import io
from collections import Counter
from PIL import Image, ImageFont, ImageDraw, ImageEnhance

from keras.datasets import mnist

#Importe de funciones especificas de bibliotecas ya importadas
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Activation, Flatten, Reshape
from keras.layers import BatchNormalization, ZeroPadding2D, Reshape
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.convolutional import UpSampling2D
from keras.optimizers import SGD, Adam

from numpy import cov
from numpy import trace
from numpy import iscomplexobj
from numpy import asarray
from numpy.random import randint
from scipy.linalg import sqrtm

from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from skimage.transform import resize
from keras.datasets.mnist import load_data

from scipy.stats import wasserstein_distance

#lineas requeridas solo en jupyter notbook
from IPython.display import clear_output
# %matplotlib notebook
# %matplotlib inline
#%tensorflow_version 2.x
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Lectura del DataSet

# %%
#Se inicia definiendo el diccionario map_characters, este posee originalmente 18
#personajes, si se agrega otro más se debe agregar al diccionario y colocarsele 
#el número consecutivo que corresponda

map_characters = {0: 'trainingCoffee'}
                  
#Se define el numero de clases con la extensión del diccionario
num_classes = len(map_characters)

#Número máximo de imagenes que se usaran por personaje para entrenar
pictures_per_class = 20000

def load_pictures(test_size, pic_size,BGR):
    """
    Load pictures from folders for characters from the map_characters dict and create a numpy dataset and 
    a numpy labels set. Pictures are re-sized into picture_size square.
    :param BGR: boolean to use true color for the picture (RGB instead of BGR for plt)
    :return: dataset, labels set
    """
    pics = []    #Se crea la lista de imagenes de salida
    labels = []  #Se crea la lista de etiquetas de salida

    #k es el numero de la variable en el diccionario
    #char es el nombre de la variable en el diccionario
    # El if lo que hace es que recorra cada una de las variables del diccionario
    for k, char in map_characters.items(): 

        #Esta linea deivuelve la lista de rutas de las imagenes de cada personaje del diccionario
        # Ej: para char = 'abraham_grampa_simpson' regresa todas las rutas de imagen de la carpeta
        # abraham_grampa_simpson que a su vez esta en la carpeta characters.
        #Es solo una forma elegante y rapida de optener todas las rutas
        pictures = [k for k in glob.glob('./source/trainingSet/%s/*' % char)]

        #Se establece la cantidad de imagenes que se van a usar en cada clase
        #Como maximo se usan 1176 imagenes, estas son tanto para train como para test
        #Si el personaje en particular tiene menos de 1176 imagenes se usara la extension del personaje en cuestion
        nb_pic = round(pictures_per_class/(1-test_size)) if round(pictures_per_class/(1-test_size))<len(pictures) else len(pictures)

        #Se usa la funcion random para ordenar de manera aleatoria las imagenes de cada personaje
        #Cabe detacar que pic es una ruta de acceso aleatoria de la lista de rutas de acceso en pictures
        for pic in np.random.choice(pictures, nb_pic):

            #Se lee la imagen de la ruta "pic"
            a = cv2.imread(pic)
            a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
            # a = cv2.imread(pic, cv2.IMREAD_GRAYSCALE)

            #Se hace un resize de las imagenes a pic_size x pic_size. Por defecoto
            #este es 64x64. Esto concuerda con los pixeles de entrada de la red neuronal
            a = cv2.resize(a, (pic_size,pic_size))

            #Se agrega la imagen leida, convertida y escalada a la lista pics
            pics.append(a)
            #Se agrega la etiqueta numérica de la lista de etiquetas, esta etiqueta numerica 
            #concuerda con el número en el diccionario map_characters
            labels.append(k)

    #Se devuelve las listas pero antes se transforman a un formato de array con numpy
    return np.array(pics), np.array(labels) 

def get_dataset(save=False, load=False, BGR=False, test_size=0.1, pic_size=64):
    #Primero se llama a la funcion load_pictures, por defecto se deja estas en 
    #blanco y negro
    #En esta funcion tambien se extraen los labels del archivo txt anotations
    X, y = load_pictures(test_size, pic_size, BGR)

    #Luego se pasa los labels a un formato numerico y en listas separadas,
    #por ejemplo si el label es 2 to_categorical lo pasa a una lista [0 0 1 ... 0]
    #El tamaño de la lista depende de cuantas clases se tenga, en este ejemplo son 18
    y = keras.utils.to_categorical(y, num_classes)

    #Se normaliza las imagenes para que los valores de cada banda esten en punto flotante
    #y además se encuentren entre 0 y 1. Esto ayuda a la velocidad de entrenamiento           
    X = X.astype('float32') / 255.
    
    #Se imprime las formas de cada tensor. Si se mantienen todas las variables 
    #por defecto estas deben ser (x,64,64,3) y (x,w), donde x es el numero de imagenes
    #y w es la cantidad de clases en el diccionario
    print("Train", X.shape, y.shape)

    return X, y

#Uso de funciones de lectura para dividir el set de imagnes en test y train
X, y = get_dataset(save=True)
# Out:
# Train (19017, 64, 64, 3) (19017, 1)

# %%
a = cv2.imread('./source/trainingSet/trainingCoffee/000001.jpg')
a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
plt.imshow(a)
plt.show()

# %% [markdown]
# # Hiper Parametros

# %%
#Dimensiones de imagen
img_rows = 64
img_cols = 64
channels = 3
latent_dim = 100
img_shape = (img_rows, img_cols, channels)
img_shape

#Filtros y configuracion de red
Filtros_Iniciales = 64
upsample_layers = 5
Kernels = 3

#Optimizador
lr  = 0.0002
b_1 = 0.5

# %% [markdown]
# # Configuración de las Redes

# %%
def build_generator():
    noise_shape = (latent_dim,)
    
    model = Sequential()

    model.add(Dense(Filtros_Iniciales * (img_rows // (2 ** upsample_layers))  *  (img_cols // (2 ** upsample_layers)), activation="relu", input_shape=noise_shape))
    model.add(Reshape(((img_rows // (2 ** upsample_layers)),
                       (img_cols // (2 ** upsample_layers)),
                       Filtros_Iniciales)))
    
    model.add(BatchNormalization(momentum=0.8))
        
    model.add(UpSampling2D())
    model.add(Conv2D(1024, kernel_size=Kernels, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))
    
    model.add(UpSampling2D())
    model.add(Conv2D(512, kernel_size=Kernels, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))
    
    model.add(UpSampling2D())
    model.add(Conv2D(256, kernel_size=Kernels, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))

    model.add(UpSampling2D())
    model.add(Conv2D(128, kernel_size=Kernels, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))
    
    model.add(UpSampling2D())
    model.add(Conv2D(64, kernel_size=Kernels, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))
    
    model.add(Conv2D(channels, kernel_size=Kernels, padding="same"))
    model.add(Activation("tanh"))
    model.add(Reshape(img_shape))

    model.summary()

    noise = Input(shape=(latent_dim,))
    fake_img = model(noise)

    return Model(noise, fake_img)


#####
def build_discriminator():

    #Se crea primeramente un modelo "Sequential", este es el tipo de red neuronal
    #existen otros tipos como las recursivas y las recurrentes.
    model = Sequential()

    model.add(Conv2D(32, (3, 3), padding='same', input_shape=img_shape))
    model.add(Activation('relu'))
    
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    
    #Finalmente se reduce a la cantidad de neuronas equivalentes a la cantidad de clases
    #que se desean, en nuestro caso, la cantidad de personajes que estamos clasificando
    model.add(Dense(1, activation='sigmoid'))

    model.summary()

    img = Input(shape=img_shape)
    validity = model(img)

    return Model(img, validity)

# %% [markdown]
# # Funciones de entrenamiento

# %%
#-------------------------------------
itr_list = []
acc_list = []
d_loss_list = []
g_loss_list = []
fid_list = []
wasserstein_distance_list = []

# %%
def train(X_train, epochs_inicial, epochs, batch_size=128, save_interval=50):
 
    #La mitad del bach es imagenes falsas y la otra mitad imagenes reales
    half_batch = int(batch_size / 2)

    # Adversarial ground truths
    valid = np.ones((half_batch, 1))
    fake = np.zeros((half_batch, 1))
    
    for epoch in range(epochs_inicial, epochs):

        # ---------------------
        #  Train Discriminator
        # ---------------------
        
        # Se seleccionan imagenes aleatorias para hacer la epoca
        idx = np.random.randint(0, X_train.shape[0], half_batch)
        imgs = X_train[idx]

        # El generador da un numero de imagenes sinteticas para la epoca
        noise = np.random.normal(0, 1, (half_batch, latent_dim))
        gen_imgs = generator.predict(noise)

        #Se entrena con las imagenes reales
        d_loss_real = discriminator.train_on_batch(imgs, valid)
        
        #Se entrena con las imagenes creadas como falsas
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)
        
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        
        # ---------------------
        #  Train Generator
        # ---------------------

        # Se ingresa el ruido al generador y la idea es que
        # el generador engañe al discriminador para que piense que es
        # una imagen real, por eso ponemos que el ruido es valido
        # Aqui solo se modifian los pesos del generador
        g_loss = combined.train_on_batch(noise, valid)
        
        #------------------------------------------
        # Calculo de Frechet Inception Distance
        #------------------------------------------
        
        ##Descomentar luego
        ## Se seleccionan imagenes aleatorias para hacer la epoca
        #idx = np.random.randint(0, X_train.shape[0], 128)
        #imgs = X_train[idx]

        ## El generador da un numero de imagenes sinteticas para la epoca
        #noise = np.random.normal(0, 1, (128, latent_dim))
        #gen_imgs = generator.predict(noise)
        #
        ## resize images
        #images1 = scale_images(imgs, (128,128,3))
        #images2 = scale_images(gen_imgs, (128,128,3))
        #
        ## pre-process images
        #images1 = preprocess_input(images1)
        #images2 = preprocess_input(images2)
        #
        ## calculate fid
        #fid = calculate_fid(model, images1, images2)
        #fid_list.append(fid)
        
        #---------------------------
        # wasserstein_distance
        #--------------------------
        
        #wasserstein_distance_list.append(wasserstein_distance([d_loss[0]], [g_loss]))       
        
        #----------------------------------------------------------------------
        #Se guarda los resultados en una lista
        itr_list.append(epoch)
        acc_list.append(100*d_loss[1])
        d_loss_list.append(d_loss[0])
        g_loss_list.append(g_loss)
        
        #----------------------------------------------------------------------
        #f, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, sharex='col', figsize=(13,7))
        #f, (ax1, ax4) = plt.subplots(2, 1, sharex='col', figsize=(13,7))
        
        #ax1.plot(itr_list, d_loss_list, label = "Discriminator Loss")
        #ax1.plot(itr_list, g_loss_list, label = "Generator Loss")
        #ax1.legend()

        ##
        #ax2.plot(itr_list, wasserstein_distance_list, '-b', label = "Wasserstein Distance")
        #ax2.legend()
        
        ##
        #ax3.plot(itr_list, fid_list, '-g', label = "Frechet Inception Distance")
        #ax3.legend()
        
        # Create two subplots and unpack the output array immediately
        #ax4.plot(itr_list, acc_list, '-r', label = "Discriminator Accuracy")
        #ax4.legend()
        
        #plt.pause(0.0002)
        #clear_output(wait=True)
        print ("%d Discriminator_loss: %f acc.: %.2f%% Generator_loss: %f" % (epoch, d_loss[0], 100*d_loss[1], g_loss))
        
        # If at save interval => save generated image samples
        if epoch % save_interval == 0:
            save_imgs(epoch)
            
        if epoch == epochs - 1:
            #Cuendo termina el entrenamiento se guardan en un df
            df = pd.DataFrame()
            df['itr'] = itr_list
            df['acc'] = acc_list
            df['d_loss'] = d_loss_list
            df['g_loss'] = g_loss_list
            #df['w_distance'] = wasserstein_distance_list
            #df['fid'] = fid_list
            df.to_csv('results.csv', index=False)

# %% [markdown]
# ## Calculo del FID

# %% [markdown]
# https://keras.io/api/applications/inceptionresnetv2/
# https://machinelearningmastery.com/how-to-implement-the-frechet-inception-distance-fid-from-scratch/

# %%
# scale an array of images to a new size
def scale_images(images, new_shape):
	images_list = list()
	for image in images:
		# resize with nearest neighbor interpolation
		new_image = resize(image, new_shape, 0)
		# store
		images_list.append(new_image)
	return asarray(images_list)

# calculate frechet inception distance
def calculate_fid(model, images1, images2):
	# calculate activations
	act1 = model.predict(images1)
	act2 = model.predict(images2)
	# calculate mean and covariance statistics
	mu1, sigma1 = act1.mean(axis=0), cov(act1, rowvar=False)
	mu2, sigma2 = act2.mean(axis=0), cov(act2, rowvar=False)
	# calculate sum squared difference between means
	ssdiff = np.sum((mu1 - mu2)**2.0)
	# calculate sqrt of product between cov
	covmean = sqrtm(sigma1.dot(sigma2))
	# check and correct imaginary numbers from sqrt
	if iscomplexobj(covmean):
		covmean = covmean.real
	# calculate score
	fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
	return fid

# this could also be the output a different Keras model or layer
input_tensor = Input(shape=(128, 128, 3))
model = InceptionV3(input_tensor=input_tensor, weights='imagenet', include_top=True)

# %%
#def save_imgs(epoch):
#    noise = np.random.normal(0, 1, (1, latent_dim))
#    gen_imgs = generator.predict(noise)
#
#    # Rescale images 0 - 1
#    gen_imgs = abs(gen_imgs)
#    gen_imgs = (abs(gen_imgs) * 255.).astype(int)
#
#    fig = plt.gcf()
#    fig.set_size_inches(64/71.5, 64/71.5)
#    ax = plt.Axes(fig, [0., 0., 1., 1.])
#    ax.axis('off')
#    fig.add_axes(ax)
#    ax.imshow(gen_imgs[0])
#    fig.savefig("ResultadosCafe/mnist_%d.png" % epoch)
#    plt.close()

def save_imgs(epoch):
    r, c = 5, 5
    noise = np.random.normal(0, 1, (r * c, latent_dim))
    gen_imgs = generator.predict(noise)

    # Rescale images 0 - 1
    gen_imgs = abs(gen_imgs)

    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow((gen_imgs[cnt] * 255).astype(int))
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("ResultadosCafe/mnist_%d.png" % epoch)
    plt.close()

# %% [markdown]
# # Main part

# %% [markdown]
# ## Entrenamiento desde cero

# %%
#Se pone el optimizador junto con los hiper parametros
optimizer = Adam(lr, b_1)

# Build and compile the discriminator
discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Build the generator
generator = build_generator()
generator.compile(loss='binary_crossentropy', optimizer=optimizer)

# The generator takes noise as input and generates imgs
z = Input(shape=(latent_dim,))
img = generator(z)

# For the combined model we will only train the generator
discriminator.trainable = False

# The discriminator takes generated images as input and determines validity
valid = discriminator(img)

# The combined model  (stacked generator and discriminator)
# Trains the generator to fool the discriminator
combined = Model(z, valid)
combined.compile(loss='binary_crossentropy', optimizer=optimizer)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_239 (Conv2D)          (None, 64, 64, 32)        896
# _________________________________________________________________
# activation_244 (Activation)  (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_240 (Conv2D)          (None, 62, 62, 32)        9248
# _________________________________________________________________
# activation_245 (Activation)  (None, 62, 62, 32)        0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 31, 31, 32)        0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_241 (Conv2D)          (None, 31, 31, 64)        18496
# _________________________________________________________________
# activation_246 (Activation)  (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_242 (Conv2D)          (None, 29, 29, 64)        36928
# _________________________________________________________________
# activation_247 (Activation)  (None, 29, 29, 64)        0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               6423040
# _________________________________________________________________
# activation_248 (Activation)  (None, 512)               0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 6,489,121
# Trainable params: 6,489,121
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 256)               25856
# _________________________________________________________________
# reshape_11 (Reshape)         (None, 2, 2, 64)          0
# _________________________________________________________________
# batch_normalization_219 (Bat (None, 2, 2, 64)          256
# _________________________________________________________________
# up_sampling2d_26 (UpSampling (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_243 (Conv2D)          (None, 4, 4, 1024)        590848
# _________________________________________________________________
# activation_249 (Activation)  (None, 4, 4, 1024)        0
# _________________________________________________________________
# batch_normalization_220 (Bat (None, 4, 4, 1024)        4096
# _________________________________________________________________
# up_sampling2d_27 (UpSampling (None, 8, 8, 1024)        0
# _________________________________________________________________
# conv2d_244 (Conv2D)          (None, 8, 8, 512)         4719104
# _________________________________________________________________
# activation_250 (Activation)  (None, 8, 8, 512)         0
# _________________________________________________________________
# batch_normalization_221 (Bat (None, 8, 8, 512)         2048
# _________________________________________________________________
# up_sampling2d_28 (UpSampling (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_245 (Conv2D)          (None, 16, 16, 256)       1179904
# _________________________________________________________________
# activation_251 (Activation)  (None, 16, 16, 256)       0
# _________________________________________________________________
# batch_normalization_222 (Bat (None, 16, 16, 256)       1024
# _________________________________________________________________
# up_sampling2d_29 (UpSampling (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_246 (Conv2D)          (None, 32, 32, 128)       295040
# _________________________________________________________________
# activation_252 (Activation)  (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_223 (Bat (None, 32, 32, 128)       512
# _________________________________________________________________
# up_sampling2d_30 (UpSampling (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_247 (Conv2D)          (None, 64, 64, 64)        73792
# _________________________________________________________________
# activation_253 (Activation)  (None, 64, 64, 64)        0
# _________________________________________________________________
# batch_normalization_224 (Bat (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_248 (Conv2D)          (None, 64, 64, 3)         1731
# _________________________________________________________________
# activation_254 (Activation)  (None, 64, 64, 3)         0
# _________________________________________________________________
# reshape_12 (Reshape)         (None, 64, 64, 3)         0
# =================================================================
# Total params: 6,894,467
# Trainable params: 6,890,371
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
#Train!!!
train(X, epochs_inicial=0, epochs=20001, batch_size=32, save_interval=100)
# Out:
# C:\Users\santi\anaconda3\envs\gpu2\lib\site-packages\keras\engine\training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 0 Discriminator_loss: 0.587948 acc.: 50.00% Generator_loss: 0.030758
# 1 Discriminator_loss: 0.633822 acc.: 50.00% Generator_loss: 0.052650
# 2 Discriminator_loss: 0.566440 acc.: 50.00% Generator_loss: 0.199394
# 3 Discriminator_loss: 0.233887 acc.: 100.00% Generator_loss: 0.417304
# 4 Discriminator_loss: 0.123172 acc.: 100.00% Generator_loss: 0.451531
# 5 Discriminator_loss: 0.047992 acc.: 100.00% Generator_loss: 0.339817
# 6 Discriminator_loss: 0.032403 acc.: 100.00% Generator_loss: 0.136865
# 7 Discriminator_loss: 0.030678 acc.: 100.00% Generator_loss: 0.193212
# 8 Discriminator_loss: 0.015866 acc.: 100.00% Generator_loss: 0.119681
# 9 Discriminator_loss: 0.009793 acc.: 100.00% Generator_loss: 0.019339
# 10 Discriminator_loss: 0.010450 acc.: 100.00% Generator_loss: 0.065634
# 11 Discriminator_loss: 0.009356 acc.: 100.00% Generator_loss: 0.056242
# 12 Discriminator_loss: 0.009223 acc.: 100.00% Generator_loss: 0.106796
# 13 Discriminator_loss: 0.008309 acc.: 100.00% Generator_loss: 0.046301
# 14 Discriminator_loss: 0.035822 acc.: 96.88% Generator_loss: 0.133485
# 15 Discriminator_loss: 0.077752 acc.: 93.75% Generator_loss: 0.778971
# 16 Discriminator_loss: 0.040166 acc.: 96.88% Generator_loss: 3.231271
# 17 Discriminator_loss: 0.041804 acc.: 100.00% Generator_loss: 2.345406
# 18 Discriminator_loss: 0.042188 acc.: 100.00% Generator_loss: 1.855112
# 19 Discriminator_loss: 0.062676 acc.: 96.88% Generator_loss: 2.451084
# 20 Discriminator_loss: 0.036816 acc.: 100.00% Generator_loss: 2.935799
# 21 Discriminator_loss: 0.178261 acc.: 96.88% Generator_loss: 4.807323
# 22 Discriminator_loss: 0.098415 acc.: 100.00% Generator_loss: 4.517271
# 23 Discriminator_loss: 0.175923 acc.: 93.75% Generator_loss: 6.125619
# 24 Discriminator_loss: 0.123328 acc.: 100.00% Generator_loss: 6.398344
# 25 Discriminator_loss: 0.263716 acc.: 93.75% Generator_loss: 6.793370
# 26 Discriminator_loss: 0.137962 acc.: 96.88% Generator_loss: 6.739597
# 27 Discriminator_loss: 0.157216 acc.: 96.88% Generator_loss: 6.313219
# 28 Discriminator_loss: 0.213831 acc.: 90.62% Generator_loss: 8.020437
# 29 Discriminator_loss: 0.205137 acc.: 100.00% Generator_loss: 7.490797
# 30 Discriminator_loss: 0.242638 acc.: 96.88% Generator_loss: 6.102670
# 31 Discriminator_loss: 0.078979 acc.: 100.00% Generator_loss: 6.737574
# 32 Discriminator_loss: 0.094532 acc.: 96.88% Generator_loss: 7.032399
# 33 Discriminator_loss: 0.216810 acc.: 93.75% Generator_loss: 7.145113
# 34 Discriminator_loss: 0.162665 acc.: 96.88% Generator_loss: 7.119446
# 35 Discriminator_loss: 0.153524 acc.: 96.88% Generator_loss: 7.852699
# 36 Discriminator_loss: 0.209973 acc.: 93.75% Generator_loss: 8.537500
# 37 Discriminator_loss: 0.223988 acc.: 96.88% Generator_loss: 7.934261
# 38 Discriminator_loss: 0.129088 acc.: 100.00% Generator_loss: 7.114477
# 39 Discriminator_loss: 0.181870 acc.: 96.88% Generator_loss: 7.660314
# 40 Discriminator_loss: 0.186131 acc.: 93.75% Generator_loss: 7.957014
# 41 Discriminator_loss: 0.126570 acc.: 96.88% Generator_loss: 7.609405
# 42 Discriminator_loss: 0.183488 acc.: 93.75% Generator_loss: 7.712881
# 43 Discriminator_loss: 0.125193 acc.: 100.00% Generator_loss: 7.704864
# 44 Discriminator_loss: 0.135834 acc.: 100.00% Generator_loss: 7.311990
# 45 Discriminator_loss: 0.171259 acc.: 96.88% Generator_loss: 8.168558
# 46 Discriminator_loss: 0.104488 acc.: 100.00% Generator_loss: 7.638777
# 47 Discriminator_loss: 0.132125 acc.: 96.88% Generator_loss: 8.049364
# 48 Discriminator_loss: 0.150794 acc.: 96.88% Generator_loss: 7.648073
# 49 Discriminator_loss: 0.159093 acc.: 96.88% Generator_loss: 8.416925
# 50 Discriminator_loss: 0.129259 acc.: 100.00% Generator_loss: 7.866485
# 51 Discriminator_loss: 0.199149 acc.: 93.75% Generator_loss: 7.750888
# 52 Discriminator_loss: 0.172501 acc.: 96.88% Generator_loss: 8.169674
# 53 Discriminator_loss: 0.111112 acc.: 100.00% Generator_loss: 8.671476
# 54 Discriminator_loss: 0.248227 acc.: 90.62% Generator_loss: 7.835690
# 55 Discriminator_loss: 0.143467 acc.: 96.88% Generator_loss: 8.420385
# 56 Discriminator_loss: 0.134356 acc.: 100.00% Generator_loss: 7.186803
# 57 Discriminator_loss: 0.109545 acc.: 100.00% Generator_loss: 7.707717
# 58 Discriminator_loss: 0.174545 acc.: 90.62% Generator_loss: 7.965876
# 59 Discriminator_loss: 0.147592 acc.: 96.88% Generator_loss: 8.096200
# 60 Discriminator_loss: 0.157050 acc.: 96.88% Generator_loss: 7.810109
# 61 Discriminator_loss: 0.218511 acc.: 87.50% Generator_loss: 8.187082
# 62 Discriminator_loss: 0.151562 acc.: 96.88% Generator_loss: 8.603373
# 63 Discriminator_loss: 0.129494 acc.: 100.00% Generator_loss: 7.404309
# 64 Discriminator_loss: 0.226046 acc.: 96.88% Generator_loss: 7.531219
# 65 Discriminator_loss: 0.162983 acc.: 96.88% Generator_loss: 8.218251
# 66 Discriminator_loss: 0.110136 acc.: 96.88% Generator_loss: 7.323027
# 67 Discriminator_loss: 0.163261 acc.: 96.88% Generator_loss: 7.288049
# 68 Discriminator_loss: 0.135452 acc.: 93.75% Generator_loss: 7.091089
# 69 Discriminator_loss: 0.143812 acc.: 93.75% Generator_loss: 7.272978
# 70 Discriminator_loss: 0.258201 acc.: 90.62% Generator_loss: 8.008578
# 71 Discriminator_loss: 0.135397 acc.: 100.00% Generator_loss: 7.893667
# 72 Discriminator_loss: 0.166640 acc.: 96.88% Generator_loss: 7.971565
# 73 Discriminator_loss: 0.156813 acc.: 96.88% Generator_loss: 7.190890
# 74 Discriminator_loss: 0.141937 acc.: 96.88% Generator_loss: 7.305261
# 75 Discriminator_loss: 0.132846 acc.: 96.88% Generator_loss: 8.173546
# 76 Discriminator_loss: 0.207369 acc.: 93.75% Generator_loss: 6.961786
# 77 Discriminator_loss: 0.083175 acc.: 100.00% Generator_loss: 7.128903
# 78 Discriminator_loss: 0.215259 acc.: 93.75% Generator_loss: 7.033968
# 79 Discriminator_loss: 0.148491 acc.: 96.88% Generator_loss: 7.305360
# 80 Discriminator_loss: 0.121032 acc.: 100.00% Generator_loss: 7.287760
# 81 Discriminator_loss: 0.129589 acc.: 96.88% Generator_loss: 6.696413
# 82 Discriminator_loss: 0.108369 acc.: 96.88% Generator_loss: 6.490211
# 83 Discriminator_loss: 0.222620 acc.: 93.75% Generator_loss: 6.283563
# 84 Discriminator_loss: 0.114981 acc.: 100.00% Generator_loss: 7.129575
# 85 Discriminator_loss: 0.159963 acc.: 93.75% Generator_loss: 6.664493
# 86 Discriminator_loss: 0.075561 acc.: 100.00% Generator_loss: 6.665164
# 87 Discriminator_loss: 0.152011 acc.: 96.88% Generator_loss: 6.288199
# 88 Discriminator_loss: 0.172905 acc.: 96.88% Generator_loss: 7.615299
# 89 Discriminator_loss: 0.131061 acc.: 100.00% Generator_loss: 6.995806
# 90 Discriminator_loss: 0.164152 acc.: 96.88% Generator_loss: 6.483183
# 91 Discriminator_loss: 0.396691 acc.: 81.25% Generator_loss: 7.298285
# 92 Discriminator_loss: 0.125166 acc.: 96.88% Generator_loss: 7.403866
# 93 Discriminator_loss: 0.187564 acc.: 90.62% Generator_loss: 6.575644
# 94 Discriminator_loss: 0.176700 acc.: 96.88% Generator_loss: 6.164860
# 95 Discriminator_loss: 0.066662 acc.: 100.00% Generator_loss: 5.588120
# 96 Discriminator_loss: 0.137910 acc.: 93.75% Generator_loss: 6.724625
# 97 Discriminator_loss: 0.177748 acc.: 90.62% Generator_loss: 6.702863
# 98 Discriminator_loss: 0.065588 acc.: 100.00% Generator_loss: 6.475981
# 99 Discriminator_loss: 0.150775 acc.: 100.00% Generator_loss: 6.319798
# 100 Discriminator_loss: 0.101091 acc.: 100.00% Generator_loss: 6.303435
# 101 Discriminator_loss: 0.104680 acc.: 100.00% Generator_loss: 5.805191
# 102 Discriminator_loss: 0.117805 acc.: 96.88% Generator_loss: 6.169943
# 103 Discriminator_loss: 0.130497 acc.: 100.00% Generator_loss: 6.109580
# 104 Discriminator_loss: 0.136310 acc.: 96.88% Generator_loss: 6.362470
# 105 Discriminator_loss: 0.155245 acc.: 93.75% Generator_loss: 5.993937
# 106 Discriminator_loss: 0.107190 acc.: 96.88% Generator_loss: 6.813505
# 107 Discriminator_loss: 0.088122 acc.: 100.00% Generator_loss: 6.543852
# 108 Discriminator_loss: 0.112409 acc.: 96.88% Generator_loss: 6.069550
# 109 Discriminator_loss: 0.175704 acc.: 93.75% Generator_loss: 6.726542
# 110 Discriminator_loss: 0.150515 acc.: 93.75% Generator_loss: 5.455379
# 111 Discriminator_loss: 0.085686 acc.: 100.00% Generator_loss: 4.960555
# 112 Discriminator_loss: 0.358964 acc.: 87.50% Generator_loss: 6.997857
# 113 Discriminator_loss: 0.111865 acc.: 100.00% Generator_loss: 6.833487
# 114 Discriminator_loss: 0.145675 acc.: 96.88% Generator_loss: 6.848423
# 115 Discriminator_loss: 0.206317 acc.: 90.62% Generator_loss: 4.858021
# 116 Discriminator_loss: 0.056474 acc.: 100.00% Generator_loss: 6.100827
# 117 Discriminator_loss: 0.151384 acc.: 93.75% Generator_loss: 5.833876
# 118 Discriminator_loss: 0.181161 acc.: 90.62% Generator_loss: 5.358907
# 119 Discriminator_loss: 0.125069 acc.: 96.88% Generator_loss: 5.136590
# 120 Discriminator_loss: 0.066733 acc.: 100.00% Generator_loss: 5.749938
# 121 Discriminator_loss: 0.169885 acc.: 93.75% Generator_loss: 5.611960
# 122 Discriminator_loss: 0.131168 acc.: 93.75% Generator_loss: 6.297409
# 123 Discriminator_loss: 0.154557 acc.: 96.88% Generator_loss: 5.656788
# 124 Discriminator_loss: 0.364915 acc.: 75.00% Generator_loss: 5.971421
# 125 Discriminator_loss: 0.135159 acc.: 96.88% Generator_loss: 6.091287
# 126 Discriminator_loss: 0.119924 acc.: 96.88% Generator_loss: 5.610326
# 127 Discriminator_loss: 0.092087 acc.: 100.00% Generator_loss: 5.205325
# 128 Discriminator_loss: 0.105015 acc.: 96.88% Generator_loss: 5.776567
# 129 Discriminator_loss: 0.107839 acc.: 100.00% Generator_loss: 5.566113
# 130 Discriminator_loss: 0.094874 acc.: 100.00% Generator_loss: 4.449631
# 131 Discriminator_loss: 0.124243 acc.: 93.75% Generator_loss: 5.228939
# 132 Discriminator_loss: 0.119598 acc.: 96.88% Generator_loss: 5.746036
# 133 Discriminator_loss: 0.150752 acc.: 96.88% Generator_loss: 6.189421
# 134 Discriminator_loss: 0.120846 acc.: 96.88% Generator_loss: 5.213429
# 135 Discriminator_loss: 0.161065 acc.: 96.88% Generator_loss: 5.513589
# 136 Discriminator_loss: 0.135716 acc.: 96.88% Generator_loss: 5.128006
# 137 Discriminator_loss: 0.123112 acc.: 100.00% Generator_loss: 5.353255
# 138 Discriminator_loss: 0.103240 acc.: 96.88% Generator_loss: 5.061321
# 139 Discriminator_loss: 0.127222 acc.: 96.88% Generator_loss: 5.469929
# 140 Discriminator_loss: 0.188738 acc.: 93.75% Generator_loss: 5.147872
# 141 Discriminator_loss: 0.125772 acc.: 96.88% Generator_loss: 4.900375
# 142 Discriminator_loss: 0.128871 acc.: 96.88% Generator_loss: 5.522794
# 143 Discriminator_loss: 0.127845 acc.: 93.75% Generator_loss: 5.268600
# 144 Discriminator_loss: 0.252177 acc.: 87.50% Generator_loss: 4.778849
# 145 Discriminator_loss: 0.218260 acc.: 90.62% Generator_loss: 5.087706
# 146 Discriminator_loss: 0.153772 acc.: 93.75% Generator_loss: 4.640710
# 147 Discriminator_loss: 0.121936 acc.: 93.75% Generator_loss: 5.225015
# 148 Discriminator_loss: 0.185916 acc.: 93.75% Generator_loss: 4.871038
# 149 Discriminator_loss: 0.130776 acc.: 96.88% Generator_loss: 4.533354
# 150 Discriminator_loss: 0.302173 acc.: 87.50% Generator_loss: 4.707926
# 151 Discriminator_loss: 0.102699 acc.: 100.00% Generator_loss: 4.780351
# 152 Discriminator_loss: 0.141965 acc.: 93.75% Generator_loss: 4.852537
# 153 Discriminator_loss: 0.118723 acc.: 100.00% Generator_loss: 5.314474
# 154 Discriminator_loss: 0.177704 acc.: 93.75% Generator_loss: 4.567642
# 155 Discriminator_loss: 0.202226 acc.: 87.50% Generator_loss: 4.583404
# 156 Discriminator_loss: 0.070080 acc.: 100.00% Generator_loss: 5.126333
# 157 Discriminator_loss: 0.115332 acc.: 96.88% Generator_loss: 4.898666
# 158 Discriminator_loss: 0.108935 acc.: 100.00% Generator_loss: 5.282835
# 159 Discriminator_loss: 0.090612 acc.: 100.00% Generator_loss: 5.002672
# 160 Discriminator_loss: 0.222691 acc.: 93.75% Generator_loss: 4.834777
# 161 Discriminator_loss: 0.092228 acc.: 96.88% Generator_loss: 4.500733
# 162 Discriminator_loss: 0.105813 acc.: 93.75% Generator_loss: 4.917287
# 163 Discriminator_loss: 0.193159 acc.: 90.62% Generator_loss: 3.898094
# 164 Discriminator_loss: 0.203680 acc.: 93.75% Generator_loss: 4.897117
# 165 Discriminator_loss: 0.064802 acc.: 100.00% Generator_loss: 4.680380
# 166 Discriminator_loss: 0.182294 acc.: 87.50% Generator_loss: 4.509313
# 167 Discriminator_loss: 0.248685 acc.: 84.38% Generator_loss: 4.679297
# 168 Discriminator_loss: 0.126211 acc.: 93.75% Generator_loss: 4.484672
# 169 Discriminator_loss: 0.225674 acc.: 87.50% Generator_loss: 4.068429
# 170 Discriminator_loss: 0.166346 acc.: 90.62% Generator_loss: 4.503329
# 171 Discriminator_loss: 0.122703 acc.: 100.00% Generator_loss: 4.124996
# 172 Discriminator_loss: 0.158509 acc.: 96.88% Generator_loss: 3.791566
# 173 Discriminator_loss: 0.222597 acc.: 87.50% Generator_loss: 4.195277
# 174 Discriminator_loss: 0.159515 acc.: 93.75% Generator_loss: 4.224714
# 175 Discriminator_loss: 0.145631 acc.: 93.75% Generator_loss: 4.081101
# 176 Discriminator_loss: 0.293986 acc.: 84.38% Generator_loss: 3.840506
# 177 Discriminator_loss: 0.186216 acc.: 96.88% Generator_loss: 4.726373
# 178 Discriminator_loss: 0.223528 acc.: 90.62% Generator_loss: 4.492344
# 179 Discriminator_loss: 0.194084 acc.: 90.62% Generator_loss: 3.816556
# 180 Discriminator_loss: 0.084456 acc.: 96.88% Generator_loss: 3.816978
# 181 Discriminator_loss: 0.091346 acc.: 96.88% Generator_loss: 3.519069
# 182 Discriminator_loss: 0.097797 acc.: 93.75% Generator_loss: 3.678491
# 183 Discriminator_loss: 0.101816 acc.: 100.00% Generator_loss: 3.843514
# 184 Discriminator_loss: 0.050040 acc.: 100.00% Generator_loss: 4.245257
# 185 Discriminator_loss: 0.254631 acc.: 90.62% Generator_loss: 3.844397
# 186 Discriminator_loss: 0.164441 acc.: 96.88% Generator_loss: 3.884902
# 187 Discriminator_loss: 0.131836 acc.: 96.88% Generator_loss: 4.230249
# 188 Discriminator_loss: 0.106546 acc.: 96.88% Generator_loss: 3.542589
# 189 Discriminator_loss: 0.233342 acc.: 87.50% Generator_loss: 3.967153
# 190 Discriminator_loss: 0.238171 acc.: 87.50% Generator_loss: 3.516678
# 191 Discriminator_loss: 0.145253 acc.: 96.88% Generator_loss: 4.205743
# 192 Discriminator_loss: 0.364144 acc.: 78.12% Generator_loss: 3.946491
# 193 Discriminator_loss: 0.102095 acc.: 100.00% Generator_loss: 4.345216
# 194 Discriminator_loss: 0.312408 acc.: 93.75% Generator_loss: 4.027976
# 195 Discriminator_loss: 0.254553 acc.: 81.25% Generator_loss: 4.402379
# 196 Discriminator_loss: 0.132691 acc.: 93.75% Generator_loss: 3.841117
# 197 Discriminator_loss: 0.192523 acc.: 93.75% Generator_loss: 4.162443
# 198 Discriminator_loss: 0.211733 acc.: 90.62% Generator_loss: 3.801550
# 199 Discriminator_loss: 0.043667 acc.: 100.00% Generator_loss: 4.092620
# 200 Discriminator_loss: 0.222328 acc.: 90.62% Generator_loss: 3.894335
# 201 Discriminator_loss: 0.129214 acc.: 93.75% Generator_loss: 3.003484
# 202 Discriminator_loss: 0.156381 acc.: 93.75% Generator_loss: 3.566889
# 203 Discriminator_loss: 0.117766 acc.: 100.00% Generator_loss: 3.544421
# 204 Discriminator_loss: 0.055129 acc.: 100.00% Generator_loss: 3.965089
# 205 Discriminator_loss: 0.119150 acc.: 96.88% Generator_loss: 3.968278
# 206 Discriminator_loss: 0.100562 acc.: 96.88% Generator_loss: 3.653219
# 207 Discriminator_loss: 0.745465 acc.: 65.62% Generator_loss: 3.696405
# 208 Discriminator_loss: 0.269339 acc.: 84.38% Generator_loss: 4.395860
# 209 Discriminator_loss: 0.131275 acc.: 96.88% Generator_loss: 4.233265
# 210 Discriminator_loss: 0.346563 acc.: 84.38% Generator_loss: 3.498934
# 211 Discriminator_loss: 0.208562 acc.: 93.75% Generator_loss: 3.573377
# 212 Discriminator_loss: 0.185202 acc.: 90.62% Generator_loss: 3.441509
# 213 Discriminator_loss: 0.306807 acc.: 84.38% Generator_loss: 3.085966
# 214 Discriminator_loss: 0.302259 acc.: 84.38% Generator_loss: 3.761520
# 215 Discriminator_loss: 0.156635 acc.: 90.62% Generator_loss: 3.329812
# 216 Discriminator_loss: 0.228006 acc.: 90.62% Generator_loss: 3.377035
# 217 Discriminator_loss: 0.126731 acc.: 96.88% Generator_loss: 3.725219
# 218 Discriminator_loss: 0.361811 acc.: 78.12% Generator_loss: 3.235716
# 219 Discriminator_loss: 0.191616 acc.: 93.75% Generator_loss: 4.221506
# 220 Discriminator_loss: 0.103922 acc.: 96.88% Generator_loss: 3.900133
# 221 Discriminator_loss: 0.320499 acc.: 84.38% Generator_loss: 3.948879
# 222 Discriminator_loss: 0.206007 acc.: 87.50% Generator_loss: 3.363836
# 223 Discriminator_loss: 0.112722 acc.: 96.88% Generator_loss: 3.791161
# 224 Discriminator_loss: 0.186880 acc.: 90.62% Generator_loss: 3.439545
# 225 Discriminator_loss: 0.287629 acc.: 87.50% Generator_loss: 3.643128
# 226 Discriminator_loss: 0.183544 acc.: 96.88% Generator_loss: 3.940531
# 227 Discriminator_loss: 0.118733 acc.: 96.88% Generator_loss: 3.474529
# 228 Discriminator_loss: 0.189453 acc.: 90.62% Generator_loss: 3.700156
# 229 Discriminator_loss: 0.267179 acc.: 84.38% Generator_loss: 3.278030
# 230 Discriminator_loss: 0.175689 acc.: 93.75% Generator_loss: 3.343274
# 231 Discriminator_loss: 0.351472 acc.: 87.50% Generator_loss: 2.977626
# 232 Discriminator_loss: 0.059429 acc.: 100.00% Generator_loss: 3.425120
# 233 Discriminator_loss: 0.292084 acc.: 84.38% Generator_loss: 3.193497
# 234 Discriminator_loss: 0.167241 acc.: 90.62% Generator_loss: 3.306662
# 235 Discriminator_loss: 0.184181 acc.: 90.62% Generator_loss: 3.442852
# 236 Discriminator_loss: 0.228996 acc.: 90.62% Generator_loss: 3.965436
# 237 Discriminator_loss: 0.264565 acc.: 90.62% Generator_loss: 3.657268
# 238 Discriminator_loss: 0.179583 acc.: 90.62% Generator_loss: 3.108384
# 239 Discriminator_loss: 0.170089 acc.: 96.88% Generator_loss: 3.227497
# 240 Discriminator_loss: 0.184485 acc.: 90.62% Generator_loss: 3.295312
# 241 Discriminator_loss: 0.119689 acc.: 96.88% Generator_loss: 3.089317
# 242 Discriminator_loss: 0.060616 acc.: 100.00% Generator_loss: 3.077732
# 243 Discriminator_loss: 0.216757 acc.: 90.62% Generator_loss: 2.997368
# 244 Discriminator_loss: 0.108672 acc.: 100.00% Generator_loss: 3.161615
# 245 Discriminator_loss: 0.199372 acc.: 90.62% Generator_loss: 3.658873
# 246 Discriminator_loss: 0.211436 acc.: 90.62% Generator_loss: 3.241760
# 247 Discriminator_loss: 0.217749 acc.: 87.50% Generator_loss: 2.917737
# 248 Discriminator_loss: 0.112718 acc.: 96.88% Generator_loss: 3.279551
# 249 Discriminator_loss: 0.135488 acc.: 96.88% Generator_loss: 3.099815
# 250 Discriminator_loss: 0.476209 acc.: 75.00% Generator_loss: 3.031572
# 251 Discriminator_loss: 0.093106 acc.: 100.00% Generator_loss: 3.111235
# 252 Discriminator_loss: 0.326518 acc.: 75.00% Generator_loss: 3.717710
# 253 Discriminator_loss: 0.190607 acc.: 93.75% Generator_loss: 3.576917
# 254 Discriminator_loss: 0.187603 acc.: 93.75% Generator_loss: 3.268395
# 255 Discriminator_loss: 0.152857 acc.: 90.62% Generator_loss: 3.243613
# 256 Discriminator_loss: 0.217063 acc.: 84.38% Generator_loss: 3.189549
# 257 Discriminator_loss: 0.167137 acc.: 90.62% Generator_loss: 3.177636
# 258 Discriminator_loss: 0.218613 acc.: 90.62% Generator_loss: 3.174203
# 259 Discriminator_loss: 0.235405 acc.: 90.62% Generator_loss: 3.456662
# 260 Discriminator_loss: 0.213164 acc.: 93.75% Generator_loss: 2.962353
# 261 Discriminator_loss: 0.200992 acc.: 93.75% Generator_loss: 3.235331
# 262 Discriminator_loss: 0.158108 acc.: 96.88% Generator_loss: 3.068565
# 263 Discriminator_loss: 0.192114 acc.: 90.62% Generator_loss: 2.723746
# 264 Discriminator_loss: 0.258239 acc.: 87.50% Generator_loss: 2.595512
# 265 Discriminator_loss: 0.190375 acc.: 90.62% Generator_loss: 2.841328
# 266 Discriminator_loss: 0.243479 acc.: 84.38% Generator_loss: 2.678747
# 267 Discriminator_loss: 0.197495 acc.: 93.75% Generator_loss: 3.120398
# 268 Discriminator_loss: 0.190284 acc.: 87.50% Generator_loss: 2.784891
# 269 Discriminator_loss: 0.347285 acc.: 81.25% Generator_loss: 3.221365
# 270 Discriminator_loss: 0.181066 acc.: 96.88% Generator_loss: 2.970023
# 271 Discriminator_loss: 0.118817 acc.: 93.75% Generator_loss: 3.695416
# 272 Discriminator_loss: 0.281981 acc.: 81.25% Generator_loss: 2.651993
# 273 Discriminator_loss: 0.132479 acc.: 96.88% Generator_loss: 3.115038
# 274 Discriminator_loss: 0.330126 acc.: 84.38% Generator_loss: 2.406273
# 275 Discriminator_loss: 0.156037 acc.: 100.00% Generator_loss: 3.104395
# 276 Discriminator_loss: 0.228116 acc.: 87.50% Generator_loss: 3.009242
# 277 Discriminator_loss: 0.211367 acc.: 90.62% Generator_loss: 2.842021
# 278 Discriminator_loss: 0.320580 acc.: 78.12% Generator_loss: 2.843480
# 279 Discriminator_loss: 0.219918 acc.: 90.62% Generator_loss: 2.942461
# 280 Discriminator_loss: 0.328253 acc.: 87.50% Generator_loss: 2.680411
# 281 Discriminator_loss: 0.218509 acc.: 93.75% Generator_loss: 2.659774
# 282 Discriminator_loss: 0.246313 acc.: 81.25% Generator_loss: 3.141260
# 283 Discriminator_loss: 0.434021 acc.: 75.00% Generator_loss: 2.544770
# 284 Discriminator_loss: 0.175424 acc.: 93.75% Generator_loss: 2.539124
# 285 Discriminator_loss: 0.223474 acc.: 87.50% Generator_loss: 3.065111
# 286 Discriminator_loss: 0.175524 acc.: 93.75% Generator_loss: 2.657346
# 287 Discriminator_loss: 0.146274 acc.: 90.62% Generator_loss: 2.524111
# 288 Discriminator_loss: 0.240500 acc.: 87.50% Generator_loss: 3.182965
# 289 Discriminator_loss: 0.232903 acc.: 84.38% Generator_loss: 2.862222
# 290 Discriminator_loss: 0.281637 acc.: 81.25% Generator_loss: 2.804232
# 291 Discriminator_loss: 0.169015 acc.: 90.62% Generator_loss: 2.641776
# 292 Discriminator_loss: 0.150534 acc.: 96.88% Generator_loss: 2.569402
# 293 Discriminator_loss: 0.332687 acc.: 81.25% Generator_loss: 2.333324
# 294 Discriminator_loss: 0.210340 acc.: 90.62% Generator_loss: 2.767031
# 295 Discriminator_loss: 0.223602 acc.: 87.50% Generator_loss: 2.874663
# 296 Discriminator_loss: 0.154549 acc.: 96.88% Generator_loss: 3.427560
# 297 Discriminator_loss: 0.096470 acc.: 100.00% Generator_loss: 2.979700
# 298 Discriminator_loss: 0.250901 acc.: 84.38% Generator_loss: 3.262841
# 299 Discriminator_loss: 0.162331 acc.: 93.75% Generator_loss: 3.229801
# 300 Discriminator_loss: 0.219019 acc.: 90.62% Generator_loss: 2.992809
# 301 Discriminator_loss: 0.209173 acc.: 84.38% Generator_loss: 2.897756
# 302 Discriminator_loss: 0.324714 acc.: 84.38% Generator_loss: 2.640792

# %% [markdown]
# ## Entrenamiento desde un punto especifico

# %%
Data = pd.read_csv('results.csv')
itr_list = list(Data.itr)
acc_list = list(Data.acc)
d_loss_list = list(Data.d_loss)
g_loss_list = list(Data.g_loss)
#wasserstein_distance_list = list(Data.w_distance)
#fid_list = list(Data.fid)

# %%
#Imprime la ultima iteracion guardada
itr_list[-1]
# Out:
# 37375

# %%
optimizer = Adam(0.0002, 0.5)

# Build and compile the discriminator
discriminator = build_discriminator()
discriminator.load_weights('discriminator_64_64_weigths.h5')
discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Build the generator
generator = build_generator()
generator.load_weights('generator_64_64_weigths.h5')
generator.compile(loss='binary_crossentropy', optimizer=optimizer)

# The generator takes noise as input and generates imgs
z = Input(shape=(latent_dim,))
img = generator(z)

# For the combined model we will only train the generator
discriminator.trainable = False

# The discriminator takes generated images as input and determines validity
valid = discriminator(img)

# The combined model  (stacked generator and discriminator)
# Trains the generator to fool the discriminator
combined = Model(z, valid)
combined.compile(loss='binary_crossentropy', optimizer=optimizer)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_95 (Conv2D)           (None, 64, 64, 32)        896
# _________________________________________________________________
# activation_95 (Activation)   (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_96 (Conv2D)           (None, 62, 62, 32)        9248
# _________________________________________________________________
# activation_96 (Activation)   (None, 62, 62, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 31, 31, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_97 (Conv2D)           (None, 31, 31, 64)        18496
# _________________________________________________________________
# activation_97 (Activation)   (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_98 (Conv2D)           (None, 29, 29, 64)        36928
# _________________________________________________________________
# activation_98 (Activation)   (None, 29, 29, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               6423040
# _________________________________________________________________
# activation_99 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 6,489,121
# Trainable params: 6,489,121
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 256)               25856
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 2, 2, 64)          0
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 2, 2, 64)          256
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_99 (Conv2D)           (None, 4, 4, 1024)        590848
# _________________________________________________________________
# activation_100 (Activation)  (None, 4, 4, 1024)        0
# _________________________________________________________________
# batch_normalization_96 (Batc (None, 4, 4, 1024)        4096
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 8, 8, 1024)        0
# _________________________________________________________________
# conv2d_100 (Conv2D)          (None, 8, 8, 512)         4719104
# _________________________________________________________________
# activation_101 (Activation)  (None, 8, 8, 512)         0
# _________________________________________________________________
# batch_normalization_97 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_101 (Conv2D)          (None, 16, 16, 256)       1179904
# _________________________________________________________________
# activation_102 (Activation)  (None, 16, 16, 256)       0
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 16, 16, 256)       1024
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_102 (Conv2D)          (None, 32, 32, 128)       295040
# _________________________________________________________________
# activation_103 (Activation)  (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_99 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_103 (Conv2D)          (None, 64, 64, 64)        73792
# _________________________________________________________________
# activation_104 (Activation)  (None, 64, 64, 64)        0
# _________________________________________________________________
# batch_normalization_100 (Bat (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_104 (Conv2D)          (None, 64, 64, 3)         1731
# _________________________________________________________________
# activation_105 (Activation)  (None, 64, 64, 3)         0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 64, 64, 3)         0
# =================================================================
# Total params: 6,894,467
# Trainable params: 6,890,371
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
train(X, epochs_inicial= 37375, epochs=40001, batch_size=32, save_interval=500)

# %%
generator.save_weights('generator_64_64_weigths.h5')
discriminator.save_weights('discriminator_64_64_weigths.h5')
combined.save_weights('combined_64_64_weigths.h5')

# %% [markdown]
# # Guardado de resultados

# %%
#Cuendo termina el entrenamiento se guardan en un df
df = pd.DataFrame()
df['itr'] = itr_list
df['acc'] = acc_list
df['d_loss'] = d_loss_list
df['g_loss'] = g_loss_list
#df['w_distance'] = wasserstein_distance_list
#df['fid'] = fid_list
df.to_csv('results.csv', index=False)

# %%
generator.save_weights('generator_64_64_weigths.h5')
discriminator.save_weights('discriminator_64_64_weigths.h5')
combined.save_weights('combined_64_64_weigths.h5')

# %%
#f, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, sharex='col', figsize=(13,7))
f, (ax1, ax4) = plt.subplots(2, 1, sharex='col', figsize=(13,7))

ax1.plot(itr_list, d_loss_list, label = "Discriminator Loss")
ax1.plot(itr_list, g_loss_list, label = "Generator Loss")
ax1.legend()

#
#ax2.plot(itr_list, wasserstein_distance_list, '-b', label = "Wasserstein Distance")
#ax2.legend()

#
#ax3.plot(itr_list, fid_list, '-g', label = "Frechet Inception Distance")
#ax3.legend()

# Create two subplots and unpack the output array immediately
ax4.plot(itr_list, acc_list, '-r', label = "Discriminator Accuracy")
ax4.legend()

# %%
from IPython.display import display
from PIL import Image

path="ResultadosCafe/mnist_0.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=64x64 at 0x2C73578B248>

# %%
from IPython.display import display
from PIL import Image

path="ResultadosCafe/mnist_40000.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=64x64 at 0x2C6285B7D88>

# %% [markdown]
# # Test con pesos guardados

# %%
optimizer = Adam(0.0002, 0.5)

new_model = build_generator()
new_model.compile(loss='binary_crossentropy', optimizer=optimizer)

new_model.load_weights('generator_64_64_weigths.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               25856
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 2, 2, 64)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2, 2, 64)          256
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 1024)        590848
# _________________________________________________________________
# activation_1 (Activation)    (None, 4, 4, 1024)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 4, 1024)        4096
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 8, 8, 1024)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 512)         4719104
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 8, 512)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       1179904
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       295040
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 64)        73792
# _________________________________________________________________
# activation_5 (Activation)    (None, 64, 64, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 3)         1731
# _________________________________________________________________
# activation_6 (Activation)    (None, 64, 64, 3)         0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 64, 64, 3)         0
# =================================================================
# Total params: 6,894,467
# Trainable params: 6,890,371
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
noise = np.random.normal(0, 1, (1,latent_dim))
gen_imgs = new_model.predict(noise)

gen_imgs2 = abs(gen_imgs)

plt.imshow((gen_imgs2[0] * 255).astype(int))
plt.show()

# %%
noise = np.random.normal(0, 1, (1,latent_dim))
gen_imgs = new_model.predict(noise)

gen_imgs2 = abs(gen_imgs)

plt.imshow((gen_imgs2[0] * 255).astype(int))
plt.show()

# %%
a = cv2.imread('./source/trainingSet/trainingCoffee/000004.jpg')
a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
plt.imshow(a)
plt.show()

# %%
a = cv2.imread('./source/trainingSet/trainingCoffee/000130.jpg')
a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
plt.imshow(a)
plt.show()

# %%
a = cv2.imread('./source/trainingSet/trainingCoffee/000302.jpg')
a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
plt.imshow(a)
plt.show()

# %% [markdown]
# # Información

# %% [markdown]
# ## https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.wasserstein_distance.html
#
#
# https://rdrr.io/cran/transport/man/wasserstein.html#:~:text=The%20Wasserstein%20distance%20of%20order%20p%20is%20defined%20as%20the,p%20of%20the%20Euclidean%20distance.
